# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('studentmat.csv')

# %%
df.head()
# Out:
#    age school sex address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0   18     GP   F       U     GT3       A     4     4  at_home   teacher  ...
# 1   17     GP   F       U     GT3       T     1     1  at_home     other  ...
# 2   15     GP   F       U     LE3       T     1     1  at_home     other  ...
# 3   15     GP   F       U     GT3       T     4     2   health  services  ...
# 4   16     GP   F       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
df1 = df.drop(['school','sex','address','Pstatus','Medu','Fedu','famsize','reason','guardian','schoolsup','famsup','nursery','higher','famrel','goout','Dalc','Walc','health'], axis='columns')

# %%
df1.head()
# Out:
#    age     Mjob      Fjob  traveltime  studytime  failures paid activities  \
# 0   18  at_home   teacher           2          2         0   no         no
# 1   17  at_home     other           1          2         0   no         no
# 2   15  at_home     other           1          2         3  yes         no
# 3   15   health  services           1          3         0  yes        yes
# 4   16    other     other           1          2         0  yes         no
#
#   internet romantic  freetime  absences  G1  G2  G3
# 0       no       no         3         6   5   6   6
# 1      yes       no         3         4   5   5   6
# 2      yes       no         3        10   7   8  10
# 3      yes      yes         2         2  15  14  15
# 4       no       no         3         4   6  10  10

# %%
df1.describe()
# Out:
#               age  traveltime   studytime    failures    freetime    absences  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    1.448101    2.035443    0.334177    3.235443    5.708861
# std      1.276043    0.697505    0.839240    0.743651    0.998862    8.003096
# min     15.000000    1.000000    1.000000    0.000000    1.000000    0.000000
# 25%     16.000000    1.000000    1.000000    0.000000    3.000000    0.000000
# 50%     17.000000    1.000000    2.000000    0.000000    3.000000    4.000000
# 75%     18.000000    2.000000    2.000000    0.000000    4.000000    8.000000
# max     22.000000    4.000000    4.000000    3.000000    5.000000   75.000000
#
#                G1          G2          G3
# count  395.000000  395.000000  395.000000
# mean    10.908861   10.713924   10.415190
# std      3.319195    3.761505    4.581443
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1['Mjob'] = le.fit_transform(df1['Mjob'])
df1['Fjob'] = le.fit_transform(df1['Fjob'])
df1['paid'] = le.fit_transform(df1['paid'])
df1['activities'] = le.fit_transform(df1['activities'])
df1['internet'] = le.fit_transform(df1['internet'])
df1['romantic'] = le.fit_transform(df1['romantic'])
df1.head()
# Out:
#    age  Mjob  Fjob  traveltime  studytime  failures  paid  activities  \
# 0   18     0     4           2          2         0     0           0
# 1   17     0     2           1          2         0     0           0
# 2   15     0     2           1          2         3     1           0
# 3   15     1     3           1          3         0     1           1
# 4   16     2     2           1          2         0     1           0
#
#    internet  romantic  freetime  absences  G1  G2  G3
# 0         0         0         3         6   5   6   6
# 1         1         0         3         4   5   5   6
# 2         1         0         3        10   7   8  10
# 3         1         1         2         2  15  14  15
# 4         0         0         3         4   6  10  10

# %%
df2 = df1
df2.head(15)
# Out:
#     age  Mjob  Fjob  traveltime  studytime  failures  paid  activities  \
# 0    18     0     4           2          2         0     0           0
# 1    17     0     2           1          2         0     0           0
# 2    15     0     2           1          2         3     1           0
# 3    15     1     3           1          3         0     1           1
# 4    16     2     2           1          2         0     1           0
# 5    16     3     2           1          2         0     1           1
# 6    16     2     2           1          2         0     0           0
# 7    17     2     4           2          2         0     0           0
# 8    15     3     2           1          2         0     1           0
# 9    15     2     2           1          2         0     1           1
# 10   15     4     1           1          2         0     1           0
# 11   15     3     2           3          3         0     0           1
# ...

# %%
df2.describe()
# Out:
#               age        Mjob        Fjob  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.169620    2.281013    1.448101    2.035443    0.334177
# std      1.276043    1.227473    0.863542    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    3.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#              paid  activities    internet    romantic    freetime    absences  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.458228    0.508861    0.832911    0.334177    3.235443    5.708861
# ...

# %%
df2.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A747381288>,
# ...
#       dtype=object)

# %%
df2[['G1','G2','G3']].plot(figsize=(20,10))

# %%
#our data to be predicted is non linear hence we will have little success doing linear regression
#predictions. So we shud now focus on classifying our data using the given features to predict
# a students performance given the conditions. hence we r going to use classification algos.

# %%
df2.isnull().sum()
# Out:
# age           0
# Mjob          0
# Fjob          0
# traveltime    0
# studytime     0
# failures      0
# paid          0
# activities    0
# internet      0
# romantic      0
# freetime      0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
#no missing values now lets look for outliers, scale and validate our data further

# %%
df2.head()
# Out:
#    age  Mjob  Fjob  traveltime  studytime  failures  paid  activities  \
# 0   18     0     4           2          2         0     0           0
# 1   17     0     2           1          2         0     0           0
# 2   15     0     2           1          2         3     1           0
# 3   15     1     3           1          3         0     1           1
# 4   16     2     2           1          2         0     1           0
#
#    internet  romantic  freetime  absences  G1  G2  G3
# 0         0         0         3         6   5   6   6
# 1         1         0         3         4   5   5   6
# 2         1         0         3        10   7   8  10
# 3         1         1         2         2  15  14  15
# 4         0         0         3         4   6  10  10

# %%
df2.head()
# Out:
#    age  Mjob  Fjob  traveltime  studytime  failures  paid  activities  \
# 0   18     0     4           2          2         0     0           0
# 1   17     0     2           1          2         0     0           0
# 2   15     0     2           1          2         3     1           0
# 3   15     1     3           1          3         0     1           1
# 4   16     2     2           1          2         0     1           0
#
#    internet  romantic  freetime  absences  G1  G2  G3
# 0         0         0         3         6   5   6   6
# 1         1         0         3         4   5   5   6
# 2         1         0         3        10   7   8  10
# 3         1         1         2         2  15  14  15
# 4         0         0         3         4   6  10  10

# %%
#shuffling data
from sklearn.model_selection import StratifiedShuffleSplit
import numpy as np

# %%
finaldf = df2
finaldf.head()
# Out:
#    age  Mjob  Fjob  traveltime  studytime  failures  paid  activities  \
# 0   18     0     4           2          2         0     0           0
# 1   17     0     2           1          2         0     0           0
# 2   15     0     2           1          2         3     1           0
# 3   15     1     3           1          3         0     1           1
# 4   16     2     2           1          2         0     1           0
#
#    internet  romantic  freetime  absences  G1  G2  G3
# 0         0         0         3         6   5   6   6
# 1         1         0         3         4   5   5   6
# 2         1         0         3        10   7   8  10
# 3         1         1         2         2  15  14  15
# 4         0         0         3         4   6  10  10

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.utils import shuffle
X = finaldf.loc[:,finaldf.columns!='G3']
y = finaldf.loc[:,'G3']
#df = df[["G1", "G2", "G3", "studytime", "failures", "absences"]]
#to be predicted final grade G3
#predict = "G3"
#we now create arrays.
#X = np.array(finaldf.drop([predict], 1))
#y = np.array(finaldf[predict])

Shuffled_X, shuffled_y = shuffle(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(Shuffled_X, shuffled_y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
from sklearn.model_selection import cross_val_score
linear.fit(X_train, y_train)
training_score = cross_val_score(linear, X_train, y_train, cv=5)
print("Linear regression model: ", "Has a training score of", round(training_score.mean(), 2) * 100, "% accuracy score")
# Out:
# Linear regression model:  Has a training score of 82.0 % accuracy score

# %%
acc = linear.score(X_test, y_test)
print("Linear regression model: ", "Has a final testing score of", round(acc.mean(), 2) * 100, "% accuracy score")
# Out:
# Linear regression model:  Has a final testing score of 79.0 % accuracy score

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt
def plot_learning_curve(estimator1,X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    f, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2,2, figsize=(20,14), sharey=True)
    if ylim is not None:
        plt.ylim(*ylim)
    # First Estimator
    train_sizes, train_scores, test_scores = learning_curve(
        estimator1, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    ax1.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="#ff9124")
    ax1.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="#2492ff")
    ax1.plot(train_sizes, train_scores_mean, 'o-', color="#ff9124",label="Training score")
    ax1.plot(train_sizes, test_scores_mean, 'o-', color="#2492ff",label="Cross-validation score")
    ax1.set_title("Linear Regression Learning Curve", fontsize=14)
    ax1.set_xlabel('Training size (m)')
    ax1.set_ylabel('Score')
    ax1.grid(True)
    ax1.legend(loc="best")

# %%
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=42)
plot_learning_curve(linear,X_train, y_train, cv=cv, n_jobs=4)
